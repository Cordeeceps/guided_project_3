# %%
import pandas as pd 

# Load the dataset as a dataframe
url = "./troop_movements10m.csv"
df = pd.read_csv(url)

# %%
# clean up unit_type data
df['unit_type'] = df['unit_type'].replace('invalid_unit', 'unknown')

# %%
# missing values before ffill
missing_before = df[['location_x', 'location_y']].isnull().sum()

# clean up location data
df['location_x'] = df['location_x'].ffill()
df['location_y'] = df['location_y'].ffill()

# count missing values after ffill
missing_after = df[['location_x', 'location_y']].isnull().sum()

# compare the counts
print("Missing values before ffill:\n", missing_before)
print("\nMissing values after ffill:\n", missing_after)
# Out:
# Missing values before ffill:
#  location_x    500
# location_y    500
# dtype: int64
#
# Missing values after ffill:
#  location_x    0
# location_y    0
# dtype: int64

# %%
! pip install pyarrow
! pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached fastparquet-2024.5.0.tar.gz (466 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached cramjam-2.8.3-cp312-none-win_amd64.whl.metadata (4.3 kB)
# ...
#   Using cached fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached cramjam-2.8.3-cp312-none-win_amd64.whl (1.6 MB)
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# ...
# Failed to build fastparquet
#   error: subprocess-exited-with-error
#
# ...

# %%
# save clean data to a parquet file 
df.to_parquet('troop_movements10m.csv')
